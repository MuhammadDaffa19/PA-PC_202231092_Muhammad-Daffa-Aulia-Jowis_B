# %% [markdown]
# # IMPORT LIBRARY

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Membaca citra asli
img = cv2.imread('Daffa.jpg')

img.shape
# Out:
# (311, 354, 3)

# %%
# Fungsi untuk menampilkan gambar
def plot_images(images, titles, cmap='gray'):
    fig, axes = plt.subplots(1, len(images), figsize=(20, 10))
    for i, ax in enumerate(axes):
        ax.imshow(cv2.cvtColor(images[i], cv2.COLOR_BGR2RGB))
        ax.set_title(titles[i])
        ax.axis('off')
    plt.show()

# %%
# Transformasi citra
# 1. Citra Asli
citra_asli = citra.copy()

# %%
# 2. Rotated
(h, w) = citra.shape[:2]
center = (w // 2, h // 2)
M = cv2.getRotationMatrix2D(center, 45, 1.0)
citra_rotated = cv2.warpAffine(citra, M, (w, h))

# %%
# 3. Resized
citra_resized = cv2.resize(citra, (w // 6, h // 4))

# %%
# 4. Cropped
start_x, start_y = w // 4, h // 4
end_x, end_y = start_x + w // 2, start_y + h // 2
citra_cropped = citra[start_y:end_y, start_x:end_x]

# %%
# 5. Flipped
citra_flipped = cv2.flip(citra, 1)

# %%
# 6. Translated
M = np.float32([[1, 0, 30], [0, 1, 30]])
citra_translated = cv2.warpAffine(citra, M, (w, h))

# %%
# Menampilkan semua gambar
images = [citra_asli, citra_rotated, citra_resized, citra_cropped, citra_flipped, citra_translated]
titles = ['Citra Asli', 'After Rotated', 'After Resized',
          'After Cropped', 'After Flipped', 'After Translated']

plot_images(images, titles)
